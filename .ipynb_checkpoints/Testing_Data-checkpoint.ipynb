# %% [markdown]
# # ***Importing Libraries***

# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # ***Test Set Image Processing***

# %%
#Using Tensorflow Keras
test_set = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/Product Recognizer/test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %% [markdown]
# # ***Loading Model***

# %%
cnn = tf.keras.models.load_model('/content/drive/MyDrive/Product Recognizer/Trained_Model.h5')

# %% [markdown]
# # ***Pre-Testing Process***

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
#Convert single image to a batch.
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 269ms/step

# %%
print(predictions)
# Out:
# [[3.4383491e-18 5.7898830e-13 8.1506112e-19 1.3473219e-22 3.4115111e-12
#   1.0247041e-20 6.8782486e-22 7.6597311e-14 1.7347992e-23 4.6222446e-14
#   6.2754792e-17 1.0028111e-12 1.0000000e+00 2.1434313e-10 1.9564023e-17
#   5.3126607e-24 4.1922557e-15 4.9932861e-13 6.0543401e-19 5.7253813e-19
#   2.1824018e-15 2.0054861e-19 4.3434075e-21 4.9084072e-16 2.0511817e-19
#   4.8522845e-13 2.8869262e-22 3.6112511e-14 5.2666031e-13 5.0901721e-15
#   3.3954836e-23 1.3503792e-13 2.2494207e-15 2.4607230e-23 2.0224247e-13
#   9.6909225e-17]]

# %%
test_set.class_names
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %% [markdown]
# # ***Testing Process***

# %% [markdown]
# ## ***Test Cases***

# %% [markdown]
# ### ***Test Case 1***

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/Product Recognizer/test/apple/Image_7.jpg'
#Reading an image in Default Mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
#Convert single image to a batch.
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 35ms/step

# %%
#Return index of max element
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 0

# %%
#Image Prediction
print("The above image is of '{}'".format(test_set.class_names[result_index].upper()))
# Out:
# The above image is of 'APPLE'

# %% [markdown]
# ### ***Test Case 2***

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/Product Recognizer/test/banana/Image_4.jpg'
#Reading an image in Default Mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
#Convert single image to a batch.
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 42ms/step

# %%
#Return index of max element
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 1

# %%
#Image Prediction
print("The above image is of '{}'".format(test_set.class_names[result_index].upper()))
# Out:
# The above image is of 'BANANA'

# %% [markdown]
# ### ***Test Case 3***

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/Product Recognizer/test/beetroot/Image_8.jpg'
#Reading an image in Default Mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
#Convert single image to a batch.
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
#Return index of max element
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 2

# %%
#Image Prediction
print("The above image is of '{}'".format(test_set.class_names[result_index].upper()))
# Out:
# The above image is of 'BEETROOT'

# %% [markdown]
# ### ***Test Case 4***

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/Product Recognizer/test/bell pepper/Image_6.jpg'
#Reading an image in Default Mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
#Convert single image to a batch.
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
#Return index of max element
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 3

# %%
#Image Prediction
print("The above image is of '{}'".format(test_set.class_names[result_index].upper()))
# Out:
# The above image is of 'BELL PEPPER'

# %% [markdown]
# ### ***Test Case 5***

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/Product Recognizer/test/cabbage/Image_4.jpg'
#Reading an image in Default Mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
#Convert single image to a batch.
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 53ms/step

# %%
#Return index of max element
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 4

# %%
#Image Prediction
print("The above image is of '{}'".format(test_set.class_names[result_index].upper()))
# Out:
# The above image is of 'CABBAGE'

# %% [markdown]
# ### ***Test Case 6***

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/Product Recognizer/test/chilli pepper/Image_5.png'
#Reading an image in Default Mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
#Convert single image to a batch.
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 47ms/step

# %%
#Return index of max element
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 8

# %%
#Image Prediction
print("The above image is of '{}'".format(test_set.class_names[result_index].upper()))
# Out:
# The above image is of 'CHILLI PEPPER'

# %% [markdown]
# ### ***Test Case 7***

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/Product Recognizer/test/corn/Image_6.jpg'
#Reading an image in Default Mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
#Convert single image to a batch.
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 100ms/step

# %%
#Return index of max element
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 9

# %%
#Image Prediction
print("The above image is of '{}'".format(test_set.class_names[result_index].upper()))
# Out:
# The above image is of 'CORN'

# %% [markdown]
# ### ***Test Case 8***

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/Product Recognizer/test/eggplant/Image_4.jpg'
#Reading an image in Default Mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
#Convert single image to a batch.
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 35ms/step

# %%
#Return index of max element
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 11

# %%
#Image Prediction
print("The above image is of '{}'".format(test_set.class_names[result_index].upper()))
# Out:
# The above image is of 'EGGPLANT'

# %% [markdown]
# ### ***Test Case 9***

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/Product Recognizer/test/garlic/Image_6.jpg'
#Reading an image in Default Mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
#Convert single image to a batch.
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
#Return index of max element
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 12

# %%
#Image Prediction
print("The above image is of '{}'".format(test_set.class_names[result_index].upper()))
# Out:
# The above image is of 'GARLIC'

# %% [markdown]
# ### ***Test Case 10***

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/Product Recognizer/test/grapes/Image_5.jpeg'
#Reading an image in Default Mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
#Convert single image to a batch.
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
#Return index of max element
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 14

# %%
#Image Prediction
print("The above image is of '{}'".format(test_set.class_names[result_index].upper()))
# Out:
# The above image is of 'GRAPES'
